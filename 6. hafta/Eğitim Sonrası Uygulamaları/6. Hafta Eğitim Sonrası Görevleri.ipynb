# %% [markdown]
# # Problem 1
# Bir sayının çift olup olmadığını sorgulayan bir fonksiyon yazın. Bu fonksiyon, eğer sayı çift ise bu değeri dönsün. Ancak sayı tek sayı ise fonksiyon raise ile ValueError hatası oluştursun. Daha sonra, içinde çift ve tek sayılar bulunduran bir liste tanımlayın ve liste üzerinde gezinerek ekrana sadece çift sayıları bastırın.

# %%
def cift(x):
    for i in x:
        if i%2 ==0:
            print(i)
        else:
            raise ValueError("Çift sayi olmayan sayi içeriyor.")

liste1 = [1,2,3,4,5,7,88,53,66,48,91,172]
list2 =[]
try:
    cift(liste1)
except ValueError:
    print("ValueError hatası oluştu")
finally:
    for çift in liste1:
        if çift%2==0 :
            list2.append(çift)
    print(list2)
# Out:
# ValueError hatası oluştu
# [2, 4, 88, 66, 48, 172]

# %% [markdown]
# # Problem 2
#
# 2 YetGen lideri ders sırasında canları sıkılınca oyun oynamak isterler. Ancak hangi oyunu oynayacaklarına karar veremezler ve son olarak kendi oyunlarını yazmaya karar verirler.
# Liderlerimizin kodlamak istediği oyun kuralları şöyledir:
# - Oyunda random olarak 0 ile 100 arasında bir sayı tutulur.
# - Kullanıcıdan bilgisayarın tuttuğu sayıyı tahmin etmesi için bir sayı girmesini istenir.
# - Eğer kullanıcının girdiği sayı bulunması gereken sayıdan küçükse  tahmininizi yükseltin, büyükse tahmininizi düşürün şeklinde bir çıktı verilir.
# - Oyunun gerçeğe yakın olması için bilgisayarın çalışmasını simgelemek için 1 saniye bekleme süresi tanınır.
# - Kullanıcı 5 hakkı vardır. 5 hakkı da kullanıp sayıyı bulamazsa oyunu kaybeder.

# %%
import random
import time
j = 5
x = int(random.uniform(0,100))

while ( j != 0 ):

    sayi = int(input("Bir sayi tahmin ediniz."))
    j -= 1
    print("İşleniyor...")
    time.sleep(1)

    if sayi == x : 
        print(f"Tebrikler sayiyi dogru bildiniz. Cevap :{x}")
        break
    elif sayi < x :
        print(f" {sayi} doğru degil.Tahmininizi yükseltin."+f"\n {j} kadar hakkınız kaldı")
    elif sayi > x :
        print(f"{sayi} doğru degil.Tahmininizi düsürünüz."+f"\n{j} kadar hakkiniz kaldi. ")
    else: 
        print("Hatali bir veri girdiniz.")

if j == 0:
    print(f"Oyunu kaybettiniz sayi: {x} idi.")
# Out:
# İşleniyor...
#  33 doğru degil.Tahmininizi yükseltin.
#  4 kadar hakkınız kaldı
# İşleniyor...
#  45 doğru degil.Tahmininizi yükseltin.
#  3 kadar hakkınız kaldı
# İşleniyor...
# 89 doğru degil.Tahmininizi düsürünüz.
# 2 kadar hakkiniz kaldi.
# İşleniyor...
#  32 doğru degil.Tahmininizi yükseltin.
#  1 kadar hakkınız kaldı
# İşleniyor...
# 67 doğru degil.Tahmininizi düsürünüz.
# 0 kadar hakkiniz kaldi.
# Oyunu kaybettiniz sayi: 62 idi.
